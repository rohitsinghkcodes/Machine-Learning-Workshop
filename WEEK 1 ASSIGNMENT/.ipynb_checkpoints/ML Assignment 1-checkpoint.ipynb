# %%
import pandas as pd

udemypath = 'udemy_courses.csv'
udemyData = pd.read_csv(udemypath)
udemyData
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemyData.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
udemyData = udemyData.dropna(axis=0)

# %%
udemyData
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemyData.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
udemyData.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
y = udemyData.price

# %%
y.describe()
# Out:
# count    3678.000000
# mean       66.049483
# std        61.005755
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
#Choosing features
features = ['course_id','is_paid',
       'num_subscribers', 'num_reviews', 'num_lectures',
       'content_duration']

# %%
X = udemyData[features]

# %%
X
# Out:
#       course_id  is_paid  num_subscribers  num_reviews  num_lectures  \
# 0       1070968     True             2147           23            51
# 1       1113822     True             2792          923           274
# 2       1006314     True             2174           74            51
# 3       1210588     True             2451           11            36
# 4       1011058     True             1276           45            26
# ...         ...      ...              ...          ...           ...
# 3673     775618     True             1040           14            21
# 3674    1088178     True              306            3            42
# 3675     635248     True              513          169            48
# 3676     905096     True              300           31            38
# 3677     297602     True              901           36            20
#
#       content_duration
# 0                  1.5
# 1                 39.0
# 2                  2.5
# 3                  3.0
# ...

# %%
X.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05      3197.150625    156.259108     40.108755
# std    3.432732e+05      9504.117010    935.452044     50.383346
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.076925e+05       111.000000      4.000000     15.000000
# 50%    6.879170e+05       911.500000     18.000000     25.000000
# 75%    9.613555e+05      2546.000000     67.000000     45.750000
# max    1.282064e+06    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
X.head()
# Out:
#    course_id  is_paid  num_subscribers  num_reviews  num_lectures  \
# 0    1070968     True             2147           23            51
# 1    1113822     True             2792          923           274
# 2    1006314     True             2174           74            51
# 3    1210588     True             2451           11            36
# 4    1011058     True             1276           45            26
#
#    content_duration
# 0               1.5
# 1              39.0
# 2               2.5
# 3               3.0
# 4               2.0

# %% [markdown]
# # Buildinng Data model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
udemyData_model = DecisionTreeRegressor(random_state=1)

# %% [markdown]
# # Fitting the model

# %%
udemyData_model.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1, splitter='best')

# %%
print('Making prediction for the following 5 courses: \n')
print(X.head())
print('\nThe predictions are:')
print(udemyData_model.predict(X.head()))
# Out:
# Making prediction for the following 5 courses:
#
#    course_id  is_paid  num_subscribers  num_reviews  num_lectures  \
# 0    1070968     True             2147           23            51
# 1    1113822     True             2792          923           274
# 2    1006314     True             2174           74            51
# 3    1210588     True             2451           11            36
# 4    1011058     True             1276           45            26
#
#    content_duration
# 0               1.5
# 1              39.0
# 2               2.5
# 3               3.0
# 4               2.0
#
# The predictions are:
# [200.  75.  45.  95. 200.]

# %% [markdown]
# # Model Validation

# %%
from sklearn.metrics import mean_absolute_error

# %%
pridict_course_prices = udemyData_model.predict(X)

# %%
mean_absolute_error(y,pridict_course_prices)
# Out:
# 0.0

# %%
from sklearn.model_selection import train_test_split

# %%
train_X,val_X,train_Y,val_Y = train_test_split(X,y,random_state = 0)

# %%
#Defining the model
udemyData_model = DecisionTreeRegressor()

# %%
udemyData_model.fit(train_X,train_Y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
val_Y.head()
# Out:
# 482      20
# 2104     40
# 3464      0
# 1422     20
# 796     200
# Name: price, dtype: int64

# %%
val_prediction = udemyData_model.predict(val_X)

# %%
print(mean_absolute_error(val_Y,val_prediction))
# Out:
# 45.82608695652174

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
def get_mae(max_leaf_nodes,train_X,val_X,train_Y,val_Y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,random_state=0)
    model.fit(train_X,train_Y)
    pred_val = model.predict(val_X)
    mae = mean_absolute_error(val_Y,pred_val)
    return mae

# %%
#comparing mae with different value of max leaf nodes
plot_1 = [5,50,500,5000]
plot_2 = []
for max_leaf_nodes in plot_1:
    my_mae = get_mae(max_leaf_nodes,train_X,val_X,train_Y,val_Y)
    print('MAx leaf nodes: %d\t\t Mean absolute error: %d'%(max_leaf_nodes,my_mae))
    plot_2.append(my_mae)
# Out:
# MAx leaf nodes: 5		 Mean absolute error: 42
# MAx leaf nodes: 50		 Mean absolute error: 39
# MAx leaf nodes: 500		 Mean absolute error: 43
# MAx leaf nodes: 5000		 Mean absolute error: 45

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(plot_2,plot_1)
# Out:
# <BarContainer object of 4 artists>
